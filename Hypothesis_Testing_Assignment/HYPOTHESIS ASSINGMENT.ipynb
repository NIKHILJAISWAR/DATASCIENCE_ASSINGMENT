# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import math
import warnings
warnings.filterwarnings("ignore")
from PIL import ImageGrab
import statsmodels.api as sm

# %%
ImageGrab.grabclipboard()

# %% [markdown]
# # <font color='red'> Question no 1

# %% [markdown]
# ImageGrab.grabclipboard![download.png](attachment:6f3b5184-bece-4357-b495-cee41e23614c.png)()

# %% [markdown]
# # We are going to conduct a 2 tailed t-Test on 2 Independent samples with Numerical Data

# %% [markdown]
#  #### We need to check whether the mean of both samples are different and
#  #### Is there any significance difference between the two samples

# %% [markdown]
# ## <font color='GOLD'>Step 1
# #### Make two Hypothesis one contradicting to other
# #### Null Hypothesis is want we want to prove

# %% [markdown]
# + **Null Hypothesis:** $\mu_1 = \mu_2$
# + **Alternative Hypthosis:** $\mu_1 \neq \mu_2$

# %% [markdown]
# ## <font color='GOLD'>Step 2

# %% [markdown]
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ### As it is a two-tailed test
# + **alpha/2 = 0.025**

# %% [markdown]
# ## <font color='GOLD'>Step 3

# %% [markdown]
# # Collect evidence

# %%
cutlets = pd.read_csv("D:\\NIKHIL JAISWAR\\ASSINGMENT\\Hypothesis_Testing_Assignment\\cutlets.csv")

# %%
cutlets
# Out:
#     Unit A  Unit B
# 0   6.8090  6.7703
# 1   6.4376  7.5093
# 2   6.9157  6.7300
# 3   7.3012  6.7878
# 4   7.4488  7.1522
# 5   7.3871  6.8110
# 6   6.8755  7.2212
# 7   7.0621  6.6606
# 8   6.6840  7.2402
# 9   6.8236  7.0503
# 10  7.3930  6.8810
# 11  7.5169  7.4059
# 12  6.9246  6.7652
# 13  6.9256  6.0380
# 14  6.5797  7.1581
# 15  6.8394  7.0240
# 16  6.5970  6.6672
# 17  7.2705  7.4314
# 18  7.2828  7.3070
# 19  7.3495  6.7478
# 20  6.9438  6.8889
# 21  7.1560  7.4220
# 22  6.5341  6.5217
# 23  7.2854  7.1688
# 24  6.9952  6.7594
# 25  6.8568  6.9399
# 26  7.2163  7.0133
# 27  6.6801  6.9182
# 28  6.9431  6.3346
# 29  7.0852  7.5459
# 30  6.7794  7.0992
# 31  7.2783  7.1180
# 32  7.1561  6.6965
# 33  7.3943  6.5780
# 34  6.9405  7.3875

# %%
cutlets.head(10)
# Out:
#    Unit A  Unit B
# 0  6.8090  6.7703
# 1  6.4376  7.5093
# 2  6.9157  6.7300
# 3  7.3012  6.7878
# 4  7.4488  7.1522
# 5  7.3871  6.8110
# 6  6.8755  7.2212
# 7  7.0621  6.6606
# 8  6.6840  7.2402
# 9  6.8236  7.0503

# %% [markdown]
# # Descriptive stats

# %%
cutlets.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %% [markdown]
# ### Checking for Null Values

# %%
cutlets.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicate Values

# %%
cutlets[cutlets.duplicated()].shape
# Out:
# (0, 2)

# %%
cutlets[cutlets.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unit A, Unit B]
# Index: []

# %% [markdown]
# ### Checking the data type

# %%
cutlets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 692.0 bytes

# %% [markdown]
# # Plotting the data

# %%
plt.subplots(figsize = (9,6))
plt.subplot(121)
plt.boxplot(cutlets['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.boxplot(cutlets['Unit B'])
plt.title('Unit B')
# Out:
# Text(0.5, 1.0, 'Unit B')

# %%
plt.subplots(figsize = (11,6))
plt.subplot(121)
plt.hist(cutlets['Unit A'],bins = 15,edgecolor ="black")
plt.title('Unit A')
plt.subplot(122)
plt.hist(cutlets['Unit B'],bins = 15,edgecolor ="black")
plt.title('Unit B')
# Out:
# Text(0.5, 1.0, 'Unit B')

# %%
plt.figure(figsize = (8,6))
labels = [ 'Unit A' , 'Unit B']
sns.distplot(cutlets['Unit A'], kde = True )
sns.distplot(cutlets['Unit B'],hist = True )
plt.legend(labels)

# %% [markdown]
# #### Create a Q-Q plot to verify if the distribution conforms to a normal distribution or not

# %%
sm.qqplot(cutlets["Unit A"], line = 'q')
plt.title('Unit A')
sm.qqplot(cutlets["Unit B"] , line = 'q')
plt.title('Unit B')
plt.show()

# %% [markdown]
# # Hypothesis using t-statistics

# %%
statistic , p_value = stats.ttest_ind(cutlets['Unit A'],cutlets['Unit B'], alternative = 'two-sided')

# %%
print('p_value=',p_value)
# Out:
# p_value= 0.4722394724599501

# %%
alpha = 0.025
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
# Out:
# Significnace=0.025, p=0.472

# %%
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between two Units A and B')
else:
    print('We fail to reject Null hypothesis')
# Out:
# We fail to reject Null hypothesis

# %% [markdown]
# # Hence, We fail to reject Null Hypothesis due to lack of evidence, there is no significant difference between the two samples¶

# %%
ImageGrab.grabclipboard()

# %% [markdown]
# # <font color='red'> Question no 2

# %% [markdown]
# ImageGrab.grabclipboard(![edcsdasas.png](attachment:d34e37f8-3041-41fc-ad19-bab657851d7f.png))

# %% [markdown]
# ## We are going to conduct a ANOVA Test on 4 Independent samples with Numerical Data

# %% [markdown]
# ### We need to check whether the mean of any of these samples are different or the same?

# %% [markdown]
# ## <font color='gold'>Step 1
# #### Make two Hypothesis one contradicting to other
# #### Null Hypothesis is want we want to prove

# %% [markdown]
# ## <font color='gold'>Step 2
# ### Decide a cut-off value

# %% [markdown]
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ## <font color='gold'>Step 3
# ### Collect evidence

# %%
labtat = pd.read_csv("D:\\NIKHIL JAISWAR\\ASSINGMENT\\Hypothesis_Testing_Assignment\\LabTAT.csv")

# %%
labtat
# Out:
#      Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0          185.35        165.53        176.70        166.13
# 1          170.49        185.91        198.45        160.79
# 2          192.77        194.92        201.23        185.18
# 3          177.33        183.00        199.61        176.42
# 4          193.41        169.57        204.63        152.60
# ..            ...           ...           ...           ...
# 115        178.49        170.66        193.80        172.68
# 116        176.08        183.98        215.25        177.64
# 117        202.48        174.54        203.99        170.27
# 118        182.40        197.18        194.52        150.87
# 119        182.09        215.17        221.49        162.21
#
# [120 rows x 4 columns]

# %%
labtat.head(10)
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60
# 5        179.45        197.00        181.51        161.12
# 6        191.37        166.36        214.21        154.02
# 7        166.81        169.60        183.43        163.25
# 8        158.81        175.36        191.60        152.79
# 9        165.88        198.68        208.43        161.98

# %% [markdown]
# ### Applying Descriptive Statistics

# %%
labtat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %% [markdown]
# ### check null values

# %%
labtat.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %% [markdown]
# ### Check duplicate values

# %%
labtat[labtat.duplicated()].shape
# Out:
# (0, 4)

# %%
labtat[labtat.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Laboratory 1, Laboratory 2, Laboratory 3, Laboratory 4]
# Index: []

# %% [markdown]
# ### Check the datatypes

# %%
labtat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %% [markdown]
# ### Plotting the data

# %%
plt.subplots(figsize = (15,9))
plt.subplot(221)
plt.boxplot(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.boxplot(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.boxplot(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.boxplot(labtat['Laboratory 4'])
plt.title('Laboratory 4')
# Out:
# Text(0.5, 1.0, 'Laboratory 4')

# %%
plt.subplots(figsize = (9,8))
plt.subplot(221)
plt.hist(labtat['Laboratory 1'])
plt.title('Laboratory 1')
plt.subplot(222)
plt.hist(labtat['Laboratory 2'])
plt.title('Laboratory 2')
plt.subplot(223)
plt.hist(labtat['Laboratory 3'])
plt.title('Laboratory 3')
plt.subplot(224)
plt.hist(labtat['Laboratory 4'])
plt.title('Laboratory 4')
# Out:
# Text(0.5, 1.0, 'Laboratory 4')

# %%
plt.figure(figsize = (8,6))
labels = ['Lab 1', 'Lab 2','Lab 3', 'Lab 4']
sns.distplot(labtat['Laboratory 1'], kde = True)
sns.distplot(labtat['Laboratory 2'],hist = True)
sns.distplot(labtat['Laboratory 3'],hist = True)
sns.distplot(labtat['Laboratory 4'],hist = True)
plt.legend(labels)

# %% [markdown]
# ### Plotting Q-Q plot to check whether the distribution follows normal distribution or not

# %%
sm.qqplot(labtat['Laboratory 1'], line = 'q')
plt.title('Laboratory 1')
sm.qqplot(labtat['Laboratory 2'], line = 'q')
plt.title('Laboratory 2')
sm.qqplot(labtat['Laboratory 3'], line = 'q')
plt.title('Laboratory 3')
sm.qqplot(labtat['Laboratory 4'], line = 'q')
plt.title('Laboratory 4')
plt.show()

# %% [markdown]
# ## <font color='gold'>Step 4

# %% [markdown]
# ### Compare Evidences with Hypothesis using t-statictic

# %%
test_statistic , p_value = stats.f_oneway(labtat.iloc[:,0],labtat.iloc[:,1],labtat.iloc[:,2],labtat.iloc[:,3])
print('p_value =',p_value)
# Out:
# p_value = 2.1156708949992414e-57

# %% [markdown]
# ### Compare p_value with '$\alpha$ '(Significane Level)

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories')
else:
    print('We fail to reject Null hypothesis')
# Out:
# Significnace=0.050, p=0.000
# We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories

# %% [markdown]
# ## Hence, We fail to reject Null Hypothesis because of lack evidence, there is no significant difference between the samples

# %% [markdown]
# # <font color='red'>Question 3

# %% [markdown]
# ImageGrab.grabclipboard(![download.png](attachment:c1692060-235e-4cc8-940b-70be165fb1b9.png))

# %% [markdown]
# ## We are going to conduct a Test of Independence</font> using Chi-Square $\chi_2$ test with Contingency table

# %% [markdown]
# ## <font color='gold'>Step 1
# #### Make two Hypothesis one contradicting to other
# #### Null Hypothesis is want we want to prove

# %% [markdown]
# + **Null Hypothesis:** There is no association or dependency between the gender based buyer rations across regions
# + **Alternative Hypthosis:** There is a significant association or dependency between the gender based buyer rations across regions

# %% [markdown]
# ## <font color='gold'>Step 2
# ### Decide a cut-off value

# %% [markdown]
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ## <font color='gold'>Step 3
# ### Collect evidence

# %% [markdown]
# ### Importing Files

# %%
buyer = pd.read_csv("D:\\NIKHIL JAISWAR\\ASSINGMENT\\Hypothesis_Testing_Assignment\\BuyerRatio.csv", index_col = 0)

# %%
buyer
# Out:
#                  East  West  North  South
# Observed Values
# Males              50   142    131     70
# Females           435  1523   1356    750

# %%
table = [[50,142,131,70],
         [435,1523,1356,750]]

# %% [markdown]
# ### Applying Chi-Square $\chi_2$ contingency table to convert observed value into expected value

# %%
stat , p , dof , exp = stats.chi2_contingency(buyer)
print(stat,"\n",p,"\n",dof,"\n",exp)
# Out:
# 1.595945538661058
#  0.6603094907091882
#  3
#  [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
stats.chi2_contingency(table)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
observed = np.array([50, 142, 131, 70, 435, 1523, 1356, 750])
expected = np.array([42.76531299,  146.81287862,  131.11756787, 72.30424052, 442.23468701, 1518.18712138, 1355.88243213, 747.69575948])

# %% [markdown]
# ## <font color='gold'>Step 4

# %% [markdown]
# ### Comparing Evidence with Hypothesis

# %%
statistics, p_value = stats.chisquare(observed, expected, ddof = 3)
print("Statistics = ",statistics,"\n",'P_Value = ', p_value)
# Out:
# Statistics =  1.5959455390914483
#  P_Value =  0.8095206646905712

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories')
else:
    print('We fail to reject Null hypothesis')
# Out:
# Significnace=0.050, p=0.810
# We fail to reject Null hypothesis

# %% [markdown]
# ## We fail to reject Null Hypothesis because of lack evidence. Therefore, there is no association or dependency between male-female buyers rations and are similar across regions. Hence, Independent samples

# %% [markdown]
# # <font color='red'>Question 4

# %% [markdown]
# ImageGrab.grabclipboard(![download.png](attachment:f1d7d71a-258a-4c38-ba0f-cef9f94defca.png))

# %% [markdown]
# ## We are going to conduct a Test of Independence using Chi-Square $\chi_2$ test with Contingency table

# %% [markdown]
# ### We need to check whether the mean of any of these samples are different or the same?

# %% [markdown]
# ## <font color='gold'>Step 1
# #### Make two Hypothesis one contradicting to other
# #### Null Hypothesis is want we want to prove

# %% [markdown]
# + **Null Hypothesis:** $\mu_1 = \mu_2$
# + **Alternative Hypthosis:** $\mu_1 \neq \mu_2$

# %% [markdown]
# ## <font color='gold'>Step 2
# ### Decide a cut-off value

# %% [markdown]
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ## <font color='gold'>Step 3
# ### Collect evidence

# %%
centers = pd.read_csv("D:\\NIKHIL JAISWAR\\ASSINGMENT\\Hypothesis_Testing_Assignment\\Costomer+OrderForm.csv")
centers.head(10)
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free
# 5   Error Free  Error Free  Error Free  Error Free
# 6   Error Free   Defective  Error Free  Error Free
# 7   Error Free  Error Free  Error Free  Error Free
# 8   Error Free  Error Free  Error Free  Error Free
# 9   Error Free  Error Free  Error Free  Error Free

# %% [markdown]
# ### Applying Descriptive Statistics

# %%
centers.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %% [markdown]
# ### Checking for Null Values

# %%
centers.isnull().sum()
# Out:
# Phillippines    0
# Indonesia       0
# Malta           0
# India           0
# dtype: int64

# %%
centers[centers.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Phillippines, Indonesia, Malta, India]
# Index: []

# %% [markdown]
# ### Checking the data type

# %%
centers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
### Checking value counts in data

# %%
print(centers['Phillippines'].value_counts(),'\n',centers['Indonesia'].value_counts(),'\n',centers['Malta'].value_counts(),'\n',centers['India'].value_counts())
# Out:
# Phillippines
# Error Free    271
# Defective      29
# Name: count, dtype: int64
#  Indonesia
# Error Free    267
# Defective      33
# Name: count, dtype: int64
#  Malta
# Error Free    269
# Defective      31
# Name: count, dtype: int64
#  India
# Error Free    280
# Defective      20
# Name: count, dtype: int64

# %% [markdown]
# ### Creating Contingency table

# %%
contingency_table = [[271,267,269,280],
                    [29,33,31,20]]
print(contingency_table)
# Out:
# [[271, 267, 269, 280], [29, 33, 31, 20]]

# %% [markdown]
# ### Calculating Expected Values for Observed data

# %%
stat, p, df, exp = stats.chi2_contingency(contingency_table)
print("Statistics = ",stat,"\n",'P_Value = ', p,'\n', 'degree of freedom =', df,'\n', 'Expected Values = ', exp)
# Out:
# Statistics =  3.858960685820355
#  P_Value =  0.2771020991233135
#  degree of freedom = 3
#  Expected Values =  [[271.75 271.75 271.75 271.75]
#  [ 28.25  28.25  28.25  28.25]]

# %% [markdown]
# ### Defining Expected values and observed values

# %%
observed = np.array([271, 267, 269, 280, 29, 33, 31, 20])
expected = np.array([271.75, 271.75, 271.75, 271.75, 28.25, 28.25, 28.25, 28.25])

# %% [markdown]
# ## <font color='gold'>Step 4

# %% [markdown]
# ### Compare Evidences with Hypothesis using t-statictic

# %%
test_statistic , p_value = stats.chisquare(observed, expected, ddof = df)
print("Test Statistic = ",test_statistic,'\n', 'p_value =',p_value)
# Out:
# Test Statistic =  3.858960685820355
#  p_value = 0.4254298144535761

# %%
alpha = 0.05
print('Significnace=%.3f, p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis there is a significance difference between TAT of reports of the laboratories')
else:
    print('We fail to reject Null hypothesis')
# Out:
# Significnace=0.050, p=0.425
# We fail to reject Null hypothesis

# %% [markdown]
# ## We fail to reject Null Hypothesis because of lack of evidence.
